# %%
import pandas as pd
data  = pd.read_csv('Bicycle_Thefts_Open_Data.csv')

# %%
#The data
data
# Out:
#                   X             Y  OBJECTID EVENT_UNIQUE_ID  \
# 0     -8.843627e+06  5.409539e+06         1  GO-20141261431
# 1     -8.838280e+06  5.409890e+06         2  GO-20141263544
# 2     -8.840400e+06  5.413056e+06         3  GO-20141263784
# 3     -8.838091e+06  5.410320e+06         4  GO-20149000090
# 4     -8.835848e+06  5.414098e+06         5  GO-20149000071
# ...             ...           ...       ...             ...
# 34285 -8.836299e+06  5.410361e+06     34286  GO-20232267483
# 34286 -8.832492e+06  5.413488e+06     34287  GO-20239048944
# 34287 -8.839466e+06  5.413924e+06     34288  GO-20239048939
# 34288 -8.822364e+06  5.424439e+06     34289  GO-20239049061
# 34289 -8.834923e+06  5.426271e+06     34290  GO-20232278820
#
#              PRIMARY_OFFENCE                OCC_DATE  OCC_YEAR  OCC_MONTH  \
# 0                THEFT UNDER  2014/01/01 05:00:00+00      2014    January
# 1                        B&E  2013/12/26 05:00:00+00      2013   December
# ...

# %%
# Description (ranger, mean, Standard deviation, etc)
data.describe()
# Out:
#                   X             Y      OBJECTID      OCC_YEAR       OCC_DAY  \
# count  3.429000e+04  3.429000e+04  34290.000000  34290.000000  34290.000000
# mean  -8.758004e+06  5.366059e+06  17145.500000   2018.296005     15.666608
# std    8.379152e+05  5.134121e+05   9898.814702      2.711279      8.623963
# min   -8.885680e+06  5.664924e-09      1.000000   1975.000000      1.000000
# 25%   -8.840859e+06  5.411469e+06   8573.250000   2016.000000      8.000000
# 50%   -8.837728e+06  5.413325e+06  17145.500000   2018.000000     16.000000
# 75%   -8.835730e+06  5.416507e+06  25717.750000   2020.000000     23.000000
# max    6.327780e-09  5.450859e+06  34290.000000   2023.000000     31.000000
#
#             OCC_DOY      OCC_HOUR   REPORT_YEAR    REPORT_DAY    REPORT_DOY  \
# count  34290.000000  34290.000000  34290.000000  34290.000000  34290.000000
# mean     199.998571     13.284369   2018.318227     15.992797    200.927442
# ...

# %%
# Types
data.dtypes
# Out:
# X                    float64
# Y                    float64
# OBJECTID               int64
# EVENT_UNIQUE_ID       object
# PRIMARY_OFFENCE       object
# OCC_DATE              object
# OCC_YEAR               int64
# OCC_MONTH             object
# OCC_DOW               object
# OCC_DAY                int64
# OCC_DOY                int64
# OCC_HOUR               int64
# REPORT_DATE           object
# REPORT_YEAR            int64
# REPORT_MONTH          object
# REPORT_DOW            object
# REPORT_DAY             int64
# REPORT_DOY             int64
# REPORT_HOUR            int64
# DIVISION              object
# LOCATION_TYPE         object
# PREMISES_TYPE         object
# BIKE_MAKE             object
# BIKE_MODEL            object
# BIKE_TYPE             object
# BIKE_SPEED           float64
# BIKE_COLOUR           object
# BIKE_COST            float64
# STATUS                object
# HOOD_158              object
# NEIGHBOURHOOD_158     object
# HOOD_140              object
# ...

# %%
# Values
df = pd.DataFrame(data)
data_values = data.iloc[0]
data_values
# Out:
# X                                     -8843627.130186
# Y                                      5409539.018644
# OBJECTID                                            1
# EVENT_UNIQUE_ID                        GO-20141261431
# PRIMARY_OFFENCE                           THEFT UNDER
# OCC_DATE                       2014/01/01 05:00:00+00
# OCC_YEAR                                         2014
# OCC_MONTH                                     January
# OCC_DOW                                     Wednesday
# OCC_DAY                                             1
# OCC_DOY                                             1
# OCC_HOUR                                            7
# REPORT_DATE                    2014/01/01 05:00:00+00
# REPORT_YEAR                                      2014
# REPORT_MONTH                                  January
# REPORT_DOW                                  Wednesday
# REPORT_DAY                                          1
# ...

# %%
# Corelation
data_corelation = df.corr()
data_corelation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Corelation
# ----> 2 data_corelation = df.corr()
#       3 data_corelation
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
# ...

# %%
#Null Values
data_null_count = data.isnull().sum()
data_null_percentage = (data.isnull().sum() / data.shape[0]) * 100
null_values = pd.DataFrame({
    'Null Count': data_null_count,
    'Null Percentage': data_null_percentage
})
null_values
# Out:
#                    Null Count  Null Percentage
# X                           0         0.000000
# Y                           0         0.000000
# OBJECTID                    0         0.000000
# EVENT_UNIQUE_ID             0         0.000000
# PRIMARY_OFFENCE             0         0.000000
# OCC_DATE                    0         0.000000
# OCC_YEAR                    0         0.000000
# OCC_MONTH                   0         0.000000
# OCC_DOW                     0         0.000000
# OCC_DAY                     0         0.000000
# OCC_DOY                     0         0.000000
# OCC_HOUR                    0         0.000000
# REPORT_DATE                 0         0.000000
# REPORT_YEAR                 0         0.000000
# REPORT_MONTH                0         0.000000
# REPORT_DOW                  0         0.000000
# REPORT_DAY                  0         0.000000
# REPORT_DOY                  0         0.000000
# REPORT_HOUR                 0         0.000000
# ...

# %%
# Visualisation in Power Bi
